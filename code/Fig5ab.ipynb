# %%
## Load python modules
import scanpy.api as sc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import scvelo as scv

# %%
adata = sc.read("../data/EpiHiRes.h5ad",
                cache = True)

# %% [markdown]
# ### Figure 5 a

# %%
scv.pl.velocity_embedding_grid(adata, basis = "umap", dpi = 200, color = "louvain", scale = .5,
                               figsize = (8, 7), density = 1)

# %% [markdown]
# ### Figure 5 b

# %%
conv = sc.read("../data/EpiHiRes_convergence.h5ad")
scv.tl.terminal_states(conv)
sc.pl.diffmap(conv, color = "end_points", components = "1, 2")
# Out:
# computing terminal states
#     identified 0 root cells and 1 end points
#     finished (0:00:01) --> added
#     'root_cells', root cells of Markov diffusion process (adata.obs)
#     'end_points', end points of Markov diffusion process (adata.obs)
